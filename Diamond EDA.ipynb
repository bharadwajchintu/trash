# %%
import pandas as pd1
import numpy as np

#import sidetable  # for frequency table

import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# for HD visualization
# %config inlineBackend.figure_format = 'retina'

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
diamond_df = pd.read_csv(r"C:\Users\Maheboob Basha\Downloads\diamonds.csv")

# %%
diamond_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamond_df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
diamond_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamond_df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# # Data Cleaning / Data Prepocessing

# %% [markdown]
# ### 1.Checking Duplicate Rows

# %%
diamond_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %% [markdown]
# ### 2. Handling Missing Values
#
#  - NaN represents the missing values
#
#  - isna() or isnull() can be used to identify the missing values

# %%
diamond_df.isna()
# Out:
#        carat    cut  color  clarity  depth  table  price      x      y      z
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
diamond_df.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamond_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # Rename the Columns

# %%
diamond_df.rename(columns={'x':'length','y':'width','z':'depth'})
# Out:
#        carat        cut color clarity  depth  table  price  length  width  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326    3.95   3.98
# 1       0.21    Premium     E     SI1   59.8   61.0    326    3.89   3.84
# 2       0.23       Good     E     VS1   56.9   65.0    327    4.05   4.07
# 3       0.29    Premium     I     VS2   62.4   58.0    334    4.20   4.23
# 4       0.31       Good     J     SI2   63.3   58.0    335    4.34   4.35
# ...      ...        ...   ...     ...    ...    ...    ...     ...    ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757    5.75   5.76
# 53936   0.72       Good     D     SI1   63.1   55.0   2757    5.69   5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757    5.66   5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757    6.15   6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757    5.83   5.87
#
#        depth
# 0       2.43
# 1       2.31
# 2       2.31
# 3       2.63
# ...

# %%
diamond_df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamond_df['color'].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamond_df['carat'].unique()
# Out:
# array([0.23, 0.21, 0.29, 0.31, 0.24, 0.26, 0.22, 0.3 , 0.2 , 0.32, 0.33,
#        0.25, 0.35, 0.42, 0.28, 0.38, 0.7 , 0.86, 0.71, 0.78, 0.96, 0.73,
#        0.8 , 0.75, 0.74, 0.81, 0.59, 0.9 , 0.91, 0.61, 0.77, 0.63, 0.76,
#        0.64, 0.72, 0.79, 0.58, 1.17, 0.6 , 0.83, 0.54, 0.98, 0.52, 1.01,
#        0.53, 0.84, 0.51, 1.05, 0.55, 0.87, 1.  , 0.57, 0.82, 1.04, 0.93,
#        1.2 , 0.99, 0.34, 0.43, 0.36, 0.95, 0.89, 1.02, 0.97, 0.56, 0.85,
#        0.92, 1.27, 0.66, 1.12, 0.68, 1.03, 0.62, 1.22, 1.08, 0.88, 0.5 ,
#        1.19, 0.39, 0.65, 1.24, 1.5 , 0.27, 0.41, 1.13, 1.06, 0.69, 0.4 ,
#        1.14, 0.94, 1.29, 1.52, 1.16, 1.21, 1.23, 1.09, 0.67, 1.11, 1.1 ,
#        1.18, 1.15, 1.25, 1.07, 1.28, 1.51, 0.37, 1.31, 1.26, 1.39, 1.44,
#        1.35, 1.3 , 1.32, 1.41, 1.36, 1.45, 1.34, 1.58, 1.54, 1.38, 1.33,
#        1.74, 1.64, 1.47, 1.4 , 1.55, 1.95, 2.  , 1.37, 1.83, 1.62, 1.57,
#        1.69, 2.06, 1.72, 1.66, 2.14, 1.49, 1.46, 2.15, 1.96, 2.22, 1.7 ,
# ...

# %%
diamond_df['clarity'].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %% [markdown]
# ### Pie Chart

# %%
diamond_df['cut'].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
# Summerizing One Categorical Variable

diamond_df['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
type(diamond_df['cut'].value_counts())
# Out:
# pandas.core.series.Series

# %%
diamond_df['cut'].value_counts().values
# Out:
# array([21551, 13791, 12082,  4906,  1610], dtype=int64)

# %%
diamond_df['cut'].value_counts().index
# Out:
# Index(['Ideal', 'Premium', 'Very Good', 'Good', 'Fair'], dtype='object')

# %%
plt.figure(figsize=(8,8));
plt.pie(x = diamond_df['cut'].value_counts().values,
        labels=diamond_df['cut'].value_counts().index,
       autopct='%.2f,%%');

# %%
plt.figure(figsize=(8,10));
plt.pie(x = diamond_df['color'].value_counts().values,
       labels=diamond_df['color'].value_counts().index,
       autopct='%.2f,%%');

# %%
plt.figure(figsize=(10,10));
plt.pie(x = diamond_df['clarity'].value_counts().values,
       labels=diamond_df['clarity'].value_counts().index,
       autopct='%.2f,%%');

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(16,8));
sns.scatterplot(data = diamond_df, x= 'carat',y = 'price',hue = 'cut');

# %%
plt.figure(figsize=(8,8))

sns.scatterplot(data = diamond_df,x = 'depth', y = 'price');

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(data = diamond_df,x = 'table', y = 'price');

# %% [markdown]
# ## Bar Plot

# %%
plt.figure(figsize=(10,8))

sns.barplot(data = diamond_df,x = 'color', y = 'price',ci = None);

# %% [markdown]
# ## Box Plot

# %%
plt.figure(figsize=(12,8))

sns.boxplot(data = diamond_df, x = 'color', y = 'price');

# %% [markdown]
# ### Distrubution Plot

# %%
plt.figure(figsize=(10,8), dpi=700);

sns.displot(data = diamond_df,x = 'price',height=10,aspect=15/5);

plt.ylabel('price', fontdict={'fontsize':40,'fontweight':'bold', 'color':'purple'})
plt.xlabel('weight',fontdict={'fontsize':40,'fontweight':'bold', 'color':'purple'});

# %% [markdown]
# # KDE Plot

# %%
plt.figure(figsize=(15,5))
sns.kdeplot(x = diamond_df.price);

# %%
plt.figure(figsize=(8,10));

sns.displot(data =diamond_df, x = 'price',height = 8,aspect = 15/5,kde = True);

plt.ylabel('count', fontdict={'fontsize':40,'fontweight':'bold', 'color':'purple'})
plt.xlabel('price',fontdict={'fontsize':40,'fontweight':'bold', 'color':'purple'});

# %% [markdown]
# ## Count Plot

# %%
plt.figure(figsize=(16,8))

sns.countplot(data = diamond_df , x = 'cut');

# %%
diamond_df.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# ### Count plot Wirt two categorical Variables

# %%
plt.figure(figsize=(18,8))

sns.countplot(data = diamond_df, x = 'cut', hue = 'color');
